# %%
conda install -c conda-forge google-colab
# Out:
# Channels:
#  - conda-forge
#  - defaults
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install --upgrade google-colab
# !pip install --upgrade google-auth
# !pip install --upgrade google-auth-oauthlib
# Out:
# Requirement already satisfied: google-colab in /opt/homebrew/anaconda3/lib/python3.12/site-packages (1.0.0)
# Requirement already satisfied: google-auth>=1.4.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from google-colab) (2.39.0)
# Requirement already satisfied: ipykernel>=4.6.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from google-colab) (6.28.0)
# Requirement already satisfied: ipython>=5.5.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from google-colab) (8.27.0)
# Requirement already satisfied: notebook>=5.2.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from google-colab) (7.2.2)
# Requirement already satisfied: six>=1.12.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from google-colab) (1.16.0)
# Requirement already satisfied: pandas>=0.24.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from google-colab) (2.2.2)
# Requirement already satisfied: portpicker>=1.2.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from google-colab) (1.6.0)
# Requirement already satisfied: requests>=2.21.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from google-colab) (2.32.3)
# Requirement already satisfied: tornado>=4.5.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from google-colab) (6.4.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from google-auth>=1.4.0->google-colab) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from google-auth>=1.4.0->google-colab) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from google-auth>=1.4.0->google-colab) (4.9.1)
# Requirement already satisfied: appnope in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from ipykernel>=4.6.0->google-colab) (0.1.3)
# Requirement already satisfied: comm>=0.1.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from ipykernel>=4.6.0->google-colab) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from ipykernel>=4.6.0->google-colab) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from ipykernel>=4.6.0->google-colab) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from ipykernel>=4.6.0->google-colab) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from ipykernel>=4.6.0->google-colab) (0.1.6)
# Requirement already satisfied: nest-asyncio in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from ipykernel>=4.6.0->google-colab) (1.6.0)
# Requirement already satisfied: packaging in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from ipykernel>=4.6.0->google-colab) (24.1)
# Requirement already satisfied: psutil in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from ipykernel>=4.6.0->google-colab) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from ipykernel>=4.6.0->google-colab) (25.1.2)
# Requirement already satisfied: traitlets>=5.4.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from ipykernel>=4.6.0->google-colab) (5.14.3)
# Requirement already satisfied: decorator in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from ipython>=5.5.0->google-colab) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from ipython>=5.5.0->google-colab) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from ipython>=5.5.0->google-colab) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from ipython>=5.5.0->google-colab) (2.15.1)
# Requirement already satisfied: stack-data in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from ipython>=5.5.0->google-colab) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from ipython>=5.5.0->google-colab) (4.8.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from notebook>=5.2.0->google-colab) (2.14.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from notebook>=5.2.0->google-colab) (2.27.3)
# Requirement already satisfied: jupyterlab<4.3,>=4.2.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from notebook>=5.2.0->google-colab) (4.2.5)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from notebook>=5.2.0->google-colab) (0.2.3)
# Requirement already satisfied: numpy>=1.26.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from pandas>=0.24.0->google-colab) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from pandas>=0.24.0->google-colab) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from pandas>=0.24.0->google-colab) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from pandas>=0.24.0->google-colab) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from requests>=2.21.0->google-colab) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from requests>=2.21.0->google-colab) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from requests>=2.21.0->google-colab) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from requests>=2.21.0->google-colab) (2025.1.31)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from jedi>=0.16->ipython>=5.5.0->google-colab) (0.8.3)
# Requirement already satisfied: platformdirs>=2.5 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.6.0->google-colab) (4.3.7)
# Requirement already satisfied: anyio>=3.1.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.2.0->google-colab) (4.2.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.2.0->google-colab) (21.3.0)
# Requirement already satisfied: jinja2>=3.0.3 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.2.0->google-colab) (3.1.4)
# Requirement already satisfied: jupyter-events>=0.9.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.2.0->google-colab) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.2.0->google-colab) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.2.0->google-colab) (7.16.4)
# Requirement already satisfied: nbformat>=5.3.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.2.0->google-colab) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.2.0->google-colab) (7.4.0)
# Requirement already satisfied: prometheus-client>=0.9 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.2.0->google-colab) (0.14.1)
# Requirement already satisfied: send2trash>=1.8.2 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.2.0->google-colab) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.2.0->google-colab) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.2.0->google-colab) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=5.2.0->google-colab) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=5.2.0->google-colab) (0.27.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=5.2.0->google-colab) (2.2.0)
# Requirement already satisfied: setuptools>=40.1.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=5.2.0->google-colab) (75.1.0)
# Requirement already satisfied: babel>=2.10 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=5.2.0->google-colab) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=5.2.0->google-colab) (0.9.6)
# Requirement already satisfied: jsonschema>=4.18.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=5.2.0->google-colab) (4.23.0)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from pexpect>4.3->ipython>=5.5.0->google-colab) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=5.5.0->google-colab) (0.2.5)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.0->google-colab) (0.4.8)
# Requirement already satisfied: executing in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from stack-data->ipython>=5.5.0->google-colab) (0.8.3)
# Requirement already satisfied: asttokens in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from stack-data->ipython>=5.5.0->google-colab) (2.0.5)
# Requirement already satisfied: pure-eval in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from stack-data->ipython>=5.5.0->google-colab) (0.2.2)
# Requirement already satisfied: sniffio>=1.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=5.2.0->google-colab) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=5.2.0->google-colab) (21.2.0)
# Requirement already satisfied: httpcore==1.* in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=5.2.0->google-colab) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=5.2.0->google-colab) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.4.0->notebook>=5.2.0->google-colab) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=5.2.0->google-colab) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=5.2.0->google-colab) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=5.2.0->google-colab) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=5.2.0->google-colab) (0.10.6)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=5.2.0->google-colab) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=5.2.0->google-colab) (6.0.1)
# Requirement already satisfied: rfc3339-validator in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=5.2.0->google-colab) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=5.2.0->google-colab) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5.2.0->google-colab) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5.2.0->google-colab) (4.1.0)
# Requirement already satisfied: defusedxml in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5.2.0->google-colab) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5.2.0->google-colab) (0.1.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5.2.0->google-colab) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5.2.0->google-colab) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5.2.0->google-colab) (1.5.0)
# Requirement already satisfied: tinycss2 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5.2.0->google-colab) (1.2.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook>=5.2.0->google-colab) (2.16.2)
# Requirement already satisfied: webencodings in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5.2.0->google-colab) (0.5.1)
# Requirement already satisfied: fqdn in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=5.2.0->google-colab) (1.5.1)
# Requirement already satisfied: isoduration in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=5.2.0->google-colab) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=5.2.0->google-colab) (2.1)
# Requirement already satisfied: uri-template in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=5.2.0->google-colab) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=5.2.0->google-colab) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=5.2.0->google-colab) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5.2.0->google-colab) (2.5)
# Requirement already satisfied: pycparser in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=5.2.0->google-colab) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=5.2.0->google-colab) (1.2.3)
# Requirement already satisfied: google-auth in /opt/homebrew/anaconda3/lib/python3.12/site-packages (2.39.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from google-auth) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from google-auth) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from google-auth) (4.9.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth) (0.4.8)
# Requirement already satisfied: google-auth-oauthlib in /opt/homebrew/anaconda3/lib/python3.12/site-packages (1.2.1)
# Requirement already satisfied: google-auth>=2.15.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from google-auth-oauthlib) (2.39.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from google-auth-oauthlib) (2.0.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from google-auth>=2.15.0->google-auth-oauthlib) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from google-auth>=2.15.0->google-auth-oauthlib) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from google-auth>=2.15.0->google-auth-oauthlib) (4.9.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.2.2)
# Requirement already satisfied: requests>=2.0.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (2.32.3)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-auth-oauthlib) (0.4.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (2025.1.31)

# %%
from google.colab import auth
from google.colab import drive
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from google.colab import auth
#       2 from google.colab import drive
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/google/colab/__init__.py:20
#      17 from __future__ import division as _
#      18 from __future__ import print_function as _
# ---> 20 from google.colab import _import_hooks
#      21 from google.colab import _installation_commands
#      22 from google.colab import _shell_customizations
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/google/colab/_import_hooks/__init__.py:16
#       1 # Copyright 2018 Google Inc.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language govestylerning permissions and
#      13 # limitations under the License.
#      14 """Colab import customizations to the IPython runtime."""
# ---> 16 from google.colab._import_hooks import _altair
#      17 from google.colab._import_hooks import _cv2
#      20 def _register_hooks():
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/google/colab/_import_hooks/_altair.py:16
#       1 # Copyright 2018 Google Inc. All rights reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      14 """Import hook for ensuring that Altair's Colab renderer is registered."""
# ---> 16 import imp
#      17 import logging
#      18 import os
#
# ModuleNotFoundError: No module named 'imp'
